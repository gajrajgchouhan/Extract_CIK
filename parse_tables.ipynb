# %%
import json
import pandas as pd

sections = json.load(open("./final_ara.json"))

# %%
for _, v in sections.items():
    if len(v["table"]) > 0:
        for table in v["table"]:
# Out:
# [                           0                  1                      2  \
# 0                        NaN                NaN                    NaN
# 1                        NaN                NaN                    NaN
# 2  Large accelerated filer x  Accelerated filer  Non-accelerated filer
#
#                            3                        4
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2  Smaller reporting company  Emerging growth company  ]
# [                 0     1      2    3   4    5      6   7
# 0              NaN   NaN    NaN  NaN NaN  NaN    NaN NaN
# 1              NaN   NaN    NaN  NaN NaN  NaN    NaN NaN
# 2           Period  High    NaN  Low NaN  NaN    NaN NaN
# 3     Fiscal 2019:   NaN    NaN  NaN NaN  NaN    NaN NaN
# 4    First quarter     $  22.55  NaN NaN    $  18.05 NaN
# 5   Second quarter     $  23.20  NaN NaN    $  19.85 NaN
# 6    Third quarter     $  20.51  NaN NaN    $  16.36 NaN
# ...
